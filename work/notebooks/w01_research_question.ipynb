# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SodiqAbdulwaris/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# **Lane: Content Refresh Prioritization (freestyle, rooted in the shipped pipeline).** I pick this because editors have limited hours and the starter data already shows ~54% of pages are "declining" — yet the obvious signal (search volume) doesn't predict traffic. A model ranked declining pages ~2.8x better than a hand rule, so this lane is both real and worth 7 weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Decision improved:** which page an editor should review or refresh *first*. **Who acts:** the SEO/content editor, who reworks the flagged page (update, consolidate, or rewrite). **Cost of a wrong call:** a false flag wastes an editor's hour on a healthy page; a missed decline lets a traffic-losing page sit untouched. Because misses (real declines left unfixed) cost ongoing traffic, the method must favor recall at the top of the queue without drowning editors in false alarms.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("rows, cols:", df.shape)
print("declining rate (label proxy):", round((df['trend_direction'].str.lower() == 'down').mean(), 3))
print("corr(search_volume, impressions_90d):", round(df['search_volume'].corr(df['impressions_90d']), 3))
vc = df[df['impressions_90d'] >= 100].groupby('content_type')['ctr'].mean().sort_values()
print("worst CTR content_type (visible):", vc.index[0], round(vc.iloc[0], 3))

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# **Can claim:** observed rates, measured CTR-by-position patterns, directional signal that a model out-ranks a hand rule on held-out clients. **Cannot claim:** causal proof, "predicting Google's algorithm," or that any flagged page *will* recover. All findings are decision-support on pseudonymized data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
